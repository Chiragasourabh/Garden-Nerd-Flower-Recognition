# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import pandas as pd

# %%
TRAIN_DATA_DIR = "data/tt"
TEST_DATA_DIR = "data/test"
IMG_SIZE = 500

# %%
path = os.path.join(TRAIN_DATA_DIR)

# %%
targetDF = pd.read_csv("data/train.csv")[:10].set_index("image_id")

# %%
# targetDF["category"][9]

# %%
Training_data = []
def create_traininf_data():
    for image in os.listdir(path):
        img_array = cv2.resize(cv2.imread(os.path.join(path,image),cv2.IMREAD_GRAYSCALE) ,(IMG_SIZE,IMG_SIZE))
        Training_data.append([img_array,targetDF["category"][int(image.split(".")[0])]])
        plt.imshow(img_array,cmap = "gray")
        plt.show()
create_traininf_data()

# %%
Training_data
# Out:
# [[array([[80, 79, 77, ..., 39, 39, 39],
#          [76, 75, 74, ..., 40, 40, 40],
#          [76, 76, 74, ..., 43, 43, 43],
#          ...,
#          [13, 14, 16, ..., 35, 34, 30],
#          [13, 17, 23, ..., 36, 36, 30],
#          [11, 19, 27, ..., 39, 37, 28]], dtype=uint8), 77],
#  [array([[172, 162, 171, ...,  73,  77,  78],
#          [183, 161, 160, ...,  71,  74,  77],
#          [174, 155, 158, ...,  66,  65,  68],
#          ...,
#          [ 35,  47,  41, ...,  18,  20,  19],
#          [ 35,  47,  42, ...,  18,  19,  18],
#          [ 34,  49,  43, ...,  17,  18,  17]], dtype=uint8), 81],
#  [array([[35, 31, 25, ..., 47, 45, 42],
#          [29, 25, 21, ..., 51, 48, 46],
#          [27, 23, 20, ..., 58, 55, 52],
#          ...,
#          [18, 16, 16, ..., 44, 41, 38],
#          [22, 16, 18, ..., 39, 39, 41],
#          [28, 18, 17, ..., 36, 40, 46]], dtype=uint8), 52],
#  [array([[146, 148, 139, ..., 124, 127, 129],
#          [163, 155, 148, ..., 123, 122, 121],
#          [164, 151, 149, ..., 123, 121, 120],
#          ...,
#          [118, 129, 123, ..., 105, 106, 107],
#          [122, 135, 134, ..., 109, 110, 111],
#          [123, 132, 136, ..., 109, 110, 111]], dtype=uint8), 72],
#  [array([[ 3,  3,  4, ..., 54, 49, 45],
#          [ 3,  3,  4, ..., 53, 49, 47],
#          [ 3,  3,  4, ..., 53, 49, 47],
#          ...,
#          [28, 24, 23, ..., 11,  9,  8],
#          [28, 24, 23, ..., 12,  9,  8],
#          [29, 25, 23, ..., 13, 10,  9]], dtype=uint8), 58],
#  [array([[12, 12, 12, ..., 13, 13, 12],
#          [13, 13, 13, ..., 13, 12, 12],
#          [14, 14, 14, ..., 11, 12, 12],
#          ...,
#          [ 9,  9,  9, ...,  4,  5,  5],
#          [ 9,  9,  9, ...,  4,  5,  5],
#          [10,  9,  8, ...,  4,  5,  5]], dtype=uint8), 2],
#  [array([[  6,  20,  30, ...,  38,  34,  32],
#          [ 28,  27,  31, ...,  33,  29,  27],
#          [ 45,  32,  32, ...,  30,  26,  24],
#          ...,
#          [147, 147, 134, ...,  31,  22,  22],
#          [113, 120, 108, ...,  31,  22,  22],
#          [ 63,  81,  72, ...,  39,  30,  30]], dtype=uint8), 75],
#  [array([[49, 49, 52, ..., 70, 68, 65],
#          [42, 41, 43, ..., 74, 73, 74],
#          [37, 34, 34, ..., 76, 73, 73],
#          ...,
#          [30, 32, 38, ..., 72, 72, 66],
#          [31, 33, 37, ..., 72, 74, 69],
#          [33, 33, 36, ..., 65, 68, 64]], dtype=uint8), 67],
#  [array([[ 92,  85,  80, ...,  66,  69,  68],
#          [ 95,  90,  86, ...,  68,  71,  71],
#          [101,  93,  87, ...,  71,  72,  71],
#          ...,
#          [112, 110, 109, ...,  97,  92,  90],
#          [115, 111, 106, ...,  98,  91,  85],
#          [111, 112, 105, ..., 103,  94,  84]], dtype=uint8), 51],
#  [array([[49, 51, 54, ..., 29, 26, 24],
#          [52, 52, 54, ..., 29, 27, 25],
#          [55, 54, 53, ..., 28, 28, 27],
#          ...,
#          [27, 29, 32, ..., 89, 86, 87],
#          [25, 25, 25, ..., 83, 79, 76],
#          [29, 27, 24, ..., 94, 87, 78]], dtype=uint8), 15]]

# %%
X = list()
y = list()

# %%
for feature , target in Training_data:
    X.append(feature)
    y.append(target)

# %%
X = np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
import pickle
pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# %%
type(y)
# Out:
# list

# %%
y = [1, 1, 0, 1, 0, 0, 0, 1, 0, 0]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 498, 498, 256)     2560
# _________________________________________________________________
# activation (Activation)      (None, 498, 498, 256)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 249, 249, 256)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 247, 247, 256)     590080
# _________________________________________________________________
# activation_1 (Activation)    (None, 247, 247, 256)     0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 123, 123, 256)     0
# _________________________________________________________________
# flatten (Flatten)            (None, 3873024)           0
# _________________________________________________________________
# dense (Dense)                (None, 64)                247873600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 248,466,305
# Trainable params: 248,466,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs = 10, batch_size = 2)

# %%
model1 = Sequential()
model1.add(Conv2D(250, (3, 3), input_shape=X.shape[1:]))
model1.add(Dense(150, activation = 'relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Conv2D(256, (3, 3)))
# model1.add(Activation('relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model1.add(Dense(64))
# model1.add(Dense(100, activation = 'relu'))
# model1.add(Dense(100, activation = 'relu'))
model1.add(Dense(102))

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 498, 498, 250)     2500
# _________________________________________________________________
# dense_14 (Dense)             (None, 498, 498, 150)     37650
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 249, 249, 150)     0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 247, 247, 256)     345856
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 123, 123, 256)     0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 3873024)           0
# _________________________________________________________________
# dense_15 (Dense)             (None, 102)               395048550
# =================================================================
# Total params: 395,434,556
# Trainable params: 395,434,556
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'] )

model1.fit(X, y, epochs = 10, batch_size = 2)

# scores = model1.evaluate(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-6615c220abaf> in <module>
#       1 model1.compile(loss = 'categorical_crossentropy' , optimizer = 'adam' , metrics = ['accuracy'] )
#       2
# ----> 3 model1.fit(X, y, epochs = 10, batch_size = 2)
#       4
#       5 # scores = model1.evaluate(X, y)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1261         steps_name='steps_per_epoch',
#    1262         steps=steps_per_epoch,
# -> 1263         validation_split=validation_split)
#    1264
#    1265     # Prepare validation data.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split)
#     905           feed_output_shapes,
#     906           check_batch_axis=False,  # Don't enforce the batch size.
# --> 907           exception_prefix='target')
#     908
#     909       # Generate sample-wise weight values given the `sample_weight` and
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     189                 'Error when checking ' + exception_prefix + ': expected ' +
#     190                 names[i] + ' to have shape ' + str(shape) +
# --> 191                 ' but got array with shape ' + str(data_shape))
#     192   return data
#     193
#
# ValueError: Error when checking target: expected dense_15 to have shape (102,) but got array with shape (1,)
